# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(torch.__version__)
print(device)
print(torch.cuda.device_count())
print(torch.cuda.current_device())
print(torch.cuda.device(0))
print(torch.cuda.get_device_name(0))
print(torch.version.cuda)
# Out:
# 2.1.1
# cuda:0
# 1
# 0
# <torch.cuda.device object at 0x7ff3f5ec7a50>
# NVIDIA A100-PCIE-40GB MIG 2g.10gb
# 12.1

# %% [markdown]
# ## Data Preprocessing

# %%
DATASET_FOLDER_NAME = 'caltech-101_top12'
dataset = torchvision.datasets.ImageFolder(root=DATASET_FOLDER_NAME)

# %%
from collections import Counter

def get_label_count(label_idxs):
    label_idxs_count = Counter(label_idxs)
    label_idxs_count = sorted(list(label_idxs_count.items()),key=lambda x:x[1] ,reverse=True)
    return label_idxs_count

label_count = get_label_count(dataset.targets)
label_count_topk = [(dataset.classes[x[0]], x[1]) for x in label_count][:20]
print(label_count_topk)
label_count_topk_total_count = sum([x[1] for x in label_count_topk])
print(label_count_topk_total_count)
# Out:
# [('airplanes', 800), ('Motorbikes', 798), ('Faces_easy', 435), ('watch', 239), ('Leopards', 200), ('bonsai', 128), ('car_side', 123), ('ketch', 114), ('chandelier', 107), ('hawksbill', 100), ('grand_piano', 99), ('brain', 98)]
# 3241

# %%
# Found minH, minW = 101, 128

# i=0
# for img, label in dataset:
#   i+=1
#   minH = min(img.shape[1], minH)
#   minW = min(img.shape[2], minW)

# print(minH, minW)

# %%
# get mean and std for dataset
import os
from time import time

class SquarePad:
    def __call__(self, image):
        max_wh = max(image.size)
        p_left, p_top = [(max_wh - s) // 2 for s in image.size]
        p_right, p_bottom = [max_wh - (s+pad) for s, pad in zip(image.size, [p_left, p_top])]
        padding = (p_left, p_top, p_right, p_bottom)
        return torchvision.transforms.functional.pad(image, padding, 0, 'constant')

def calc_mean_std(loader, N_CHANNELS = 3):
    before = time()
    mean = torch.zeros(3)
    std = torch.zeros(3)
    print('==> Computing mean and std..')
    for inputs, _labels in full_loader:
        for i in range(N_CHANNELS):
            mean[i] += inputs[:,i,:,:].mean()
            std[i] += inputs[:,i,:,:].std()
    mean.div_(len(dataset))
    std.div_(len(dataset))
    print('mean:', mean, 'std:', std)
    print("time elapsed: ", time()-before)
    return mean, std

IMAGE_SIZE = 128

dataset.transform = transforms.Compose([SquarePad(),
                                        transforms.ToTensor(),
                                        transforms.Resize((IMAGE_SIZE, IMAGE_SIZE), antialias=True)])

full_loader = torch.utils.data.DataLoader(dataset)

mean, std = calc_mean_std(full_loader)
# Out:
# ==> Computing mean and std..
# mean: tensor([0.3585, 0.3530, 0.3410]) std: tensor([0.3140, 0.3121, 0.3101])
# time elapsed:  11.358381748199463

# %%
from sklearn.model_selection import train_test_split
import numpy as np
from torch.utils.data import Subset

# set seed
torch.manual_seed(123)

IMAGE_SIZE = 128

dataset.transform = transforms.Compose([SquarePad(),
                                        transforms.ToTensor(),
                                        transforms.Resize((IMAGE_SIZE, IMAGE_SIZE), antialias=True),
                                        transforms.CenterCrop(size=IMAGE_SIZE),
                                        transforms.Normalize(mean, std)])

labels = dataset.targets
print("Count of all data:", len(labels))

train_idx, val_test_idx = train_test_split(np.arange(len(labels)),
                                           test_size=0.2,
                                           shuffle=True,
                                           random_state=100,
                                           stratify=labels)

val_test_labels = [dataset.targets[x] for x in val_test_idx]

val_idx, test_idx = train_test_split(np.arange(len(val_test_labels)),
                                      test_size=0.5,
                                      shuffle=True,
                                      random_state=102,
                                      stratify=val_test_labels)

val_idx = [val_test_idx[x] for x in val_idx]
test_idx = [val_test_idx[x] for x in test_idx]

train_data_count = len(train_idx)
val_data_count = len(val_idx)
test_data_count = len(test_idx)

print("Count of train data:", train_data_count)
print("Count of val data:", val_data_count)
print("Count of test data:", test_data_count)

train_data = Subset(dataset, train_idx)
val_data = Subset(dataset, val_idx)
test_data = Subset(dataset, test_idx)
# assert no intersection
assert(len(set().intersection(train_idx, val_idx, test_idx))==0)
# Out:
# Count of all data: 3241
# Count of train data: 2592
# Count of val data: 324
# Count of test data: 325

# %%
from collections import Counter

train_labels = [dataset.targets[x] for x in train_idx]
val_labels = [dataset.targets[x] for x in val_idx]
test_labels = [dataset.targets[x] for x in test_idx]

print(sorted(Counter(train_labels).items()))
print(sorted(Counter(val_labels).items()))
print(sorted(Counter(test_labels).items()))
# Out:
# [(0, 348), (1, 160), (2, 638), (3, 640), (4, 102), (5, 79), (6, 98), (7, 86), (8, 79), (9, 80), (10, 91), (11, 191)]
# [(0, 43), (1, 20), (2, 80), (3, 80), (4, 13), (5, 10), (6, 12), (7, 11), (8, 10), (9, 10), (10, 11), (11, 24)]
# [(0, 44), (1, 20), (2, 80), (3, 80), (4, 13), (5, 9), (6, 13), (7, 10), (8, 10), (9, 10), (10, 12), (11, 24)]

# %%
import matplotlib.pyplot as plt

def show_img_grid(images, nrow=5):
  grid_img = torchvision.utils.make_grid(images, nrow=nrow)
  plt.imshow(grid_img.permute(1, 2, 0))

# %%
train_loader = torch.utils.data.DataLoader(train_data, batch_size=16, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=16, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=16, shuffle=False)


x, y = next(iter(train_loader))
print(x.shape, y.shape)
show_img_grid(x[0]*std.view(3, 1, 1)+mean.view(3, 1, 1), 1)
image, label = x[0], y[0].item()
print(dataset.classes[label])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([16, 3, 128, 128]) torch.Size([16])
# Motorbikes

# %% [markdown]
# ## CNN Class

# %%
# Model with x conv-relu-maxpool blocks and 2 fc layers

class ConvNet(nn.Module):
  def __init__(self, conv_layer_channels = [2, 4], conv_layer_sizes = [3, 3], hidden_layers=[128, 64], dropout_p=0.5, cin = 3):
    super(ConvNet, self).__init__()
    # make sure length is equal
    assert(len(conv_layer_channels)==len(conv_layer_sizes))
    # number of conv layers
    num_conv_layers = len(conv_layer_channels)
    # c[i] = input channels of ith layer, c[i+1] = output channels of ith layer
    c = [cin] + conv_layer_channels
    # create conv-relu-maxpool blocks
    conv_blocks = [nn.Sequential(
                        nn.Conv2d(c[i], c[i+1], conv_layer_sizes[i], padding='same', bias=True),
                        nn.ReLU(),
                        nn.MaxPool2d((2,2))
                    ) for i in range(num_conv_layers)]
    self.conv_block = nn.Sequential(*conv_blocks)
    # calculate width of feature map after conv blocks
    w = IMAGE_SIZE // 2**num_conv_layers
    
    # number of fc hidden layers
    num_fc_layers = len(hidden_layers)
    # h[i] = input dim of ith fc layer, h[i+1] = output dim of ith fc layer
    h = [conv_layer_channels[-1]*w*w] + hidden_layers
    fc_blocks = [nn.Sequential(
                        nn.Linear(h[i], h[i+1], bias=True),
                        nn.ReLU()
                    ) for i in range(num_fc_layers)]
    self.fc_block = nn.Sequential(*fc_blocks)
    # last fc layer that produces 12 class scores
    self.scoring = nn.Linear(h[-1], 12, bias=True)
    # dropout layer before fc layers
    self.dropout = nn.Dropout(p=dropout_p)

  def forward(self, x):
    x = self.conv_block(x)
    x = torch.flatten(x, 1) # flatten all dimensions except the batch dimension
    x = self.dropout(x)
    x = self.fc_block(x)
    x = self.scoring(x)
    return x



net = ConvNet()
print(net)

test_tensor = torch.randn(1, 3, IMAGE_SIZE, IMAGE_SIZE)
out = net(test_tensor)
print(out.shape)
print(out)
# Out:
# ConvNet(
#   (conv_block): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 2, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): Sequential(
#       (0): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (fc_block): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=4096, out_features=128, bias=True)
#       (1): ReLU()
#     )
#     (1): Sequential(
#       (0): Linear(in_features=128, out_features=64, bias=True)
#       (1): ReLU()
#     )
#   )
#   (scoring): Linear(in_features=64, out_features=12, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )
# torch.Size([1, 12])
# tensor([[-0.0744, -0.0708, -0.0978, -0.1102, -0.1246, -0.1030,  0.1026,  0.0281,
#           0.0426,  0.1043, -0.1263,  0.0252]], grad_fn=<AddmmBackward0>)

# %%
# evaluation function

def eval(model, criterion, val_loader):
    total = correct = 0
    running_loss = 0.0
    with torch.no_grad():
        for data in val_loader:
            model.eval()
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            
            scores = model(images)
            loss = criterion(scores, labels)
            
            running_loss += loss.item() * labels.size(0)
            
            _, predicted = torch.max(scores.data, 1)
            
            total += labels.size(0)
            
            correct += (predicted == labels).sum().item()
    return running_loss / total, 100 * correct // total

# %%
import torch.optim as optim
import torch

# set seed
torch.manual_seed(123)

# Early Stopper
class EarlyStopper:
    def __init__(self, patience=5, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.min_validation_loss = float('inf')

    def early_stop(self, validation_loss):
        if validation_loss < self.min_validation_loss:
            self.min_validation_loss = validation_loss
            self.counter = 0
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# Train loop
def train(model, train_loader, epochs, optimizer, criterion, val_loader, print_every=1, print_time=False):
    early_stopper = EarlyStopper(patience=10, min_delta=0)
    num_iters = epochs * len(train_loader)
    iter = 0
    train_loss_history = []
    train_acc_history = []
    val_loss_history = []
    val_acc_history = []
    before = time()
    for epoch in range(epochs):
        total = correct = 0
        running_loss = 0.0
        for i, data in enumerate(train_loader):
            iter+=1
            model.train()
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()

            scores = model(images)
            loss = criterion(scores, labels)
            
            running_loss += loss.item() * labels.size(0)

            _, predicted = torch.max(scores.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            loss.backward()
            optimizer.step()
            
        train_loss = running_loss / total
        train_acc = 100 * correct // total
        
        val_loss, val_accuracy = eval(model, criterion, val_loader)
        
        if epoch % print_every==0 or epoch==epochs-1:
            print(f'[Epoch {epoch + 1}] training loss and accuracy: {train_loss:.3f} {train_acc} %')
            print(f'[Epoch {epoch + 1}] validation loss and accuracy: {val_loss:.3f} {val_accuracy} %')
        
        train_loss_history.append(train_loss)
        train_acc_history.append(train_acc)
        val_loss_history.append(val_loss)
        val_acc_history.append(val_accuracy)
        
        
        if early_stopper.early_stop(val_loss):             
            break
        
    if print_time:
        print("time elapsed: ", time()-before)
    return train_loss_history, train_acc_history, val_loss_history, val_acc_history

# %%
# Grid search function
def grid_search(models, hyperparameters, train_loader, val_loader, NUM_EPOCHS):
    before = time()
    # stores best model and hyperparameter
    best_model_hyperparam = {
        'model': None,
        'lr': None,
        'momentum': None,
        'weight_decay': None
    }
    # stores best validation accuracy
    best_val_acc = -1
    
    lrs = hyperparameters['lr']
    momentums = hyperparameters['momentum']
    weight_decays = hyperparameters['weight_decay']
    for i, model in enumerate(models):
        for lr in lrs:
            for momentum in momentums:
                for weight_decay in weight_decays:
                    # init model
                    net = ConvNet(*model)
                    net.to(device)
                    print(f'Model {i} with learning rate={lr}, momentum={momentum}, weight_decay={weight_decay}')
                    
                    # init loss and optimizer
                    criterion = nn.CrossEntropyLoss()
                    optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
                    
                    # train
                    train_loss_history, train_acc_history, val_loss_history, val_acc_history = \
                        train(net, train_loader, NUM_EPOCHS, optimizer, criterion, val_loader, print_every=5, print_time=False)
                    
                    # update best_model_hyperparam based on max validation accuracy
                    max_val_acc = np.max(val_acc_history)
                    if max_val_acc > best_val_acc:
                        best_val_acc = max_val_acc
                        best_model_hyperparam = {
                            'model': model,
                            'lr': lr,
                            'momentum': momentum,
                            'weight_decay': weight_decay
                        }
                    print(f'Best validation accuracy:', max_val_acc, '%')
                    print('======================================================')
    print('Best model and hyperparameter:', best_model_hyperparam)
    print('Best validation accuracy:', best_val_acc, '%')
    print("time elapsed: ", time()-before)
    return best_model_hyperparam

# %% [markdown]
# ## Grid Search Hyperparameters

# %%
torch.manual_seed(123)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=32,shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=32, shuffle=False)

hyperparameters = {
    'lr': [1e-2, 1e-3, 5e-4],
    'momentum': [0.9],
    'weight_decay': [0, 1e-2]
}

models = [
    [[4, 8], [3, 3], [32], 0.2, 3],
    [[4, 8], [5, 5], [64], 0.2, 3],
    [[16, 32], [5, 3], [128], 0.2, 3],
    [[8, 32, 64], [5, 3, 3], [128], 0.5, 3],
    [[12, 64, 128], [5, 3, 3], [512, 64], 0.5, 3],
]

NUM_EPOCHS=50

best_model_hyperparam = grid_search(models, hyperparameters, train_loader, val_loader, NUM_EPOCHS)
# Out:
# Model 0 with learning rate=0.01, momentum=0.9, weight_decay=0
# [Epoch 1] training loss and accuracy: 1.165 63 %
# [Epoch 1] validation loss and accuracy: 0.730 77 %
# [Epoch 6] training loss and accuracy: 0.121 96 %
# [Epoch 6] validation loss and accuracy: 0.387 88 %
# [Epoch 11] training loss and accuracy: 0.016 99 %
# [Epoch 11] validation loss and accuracy: 0.460 90 %
# [Epoch 16] training loss and accuracy: 0.000 100 %
# [Epoch 16] validation loss and accuracy: 0.485 91 %
# Best validation accuracy: 91 %
# ======================================================
# Model 0 with learning rate=0.01, momentum=0.9, weight_decay=0.01
# [Epoch 1] training loss and accuracy: 1.356 58 %
# [Epoch 1] validation loss and accuracy: 0.878 73 %
# [Epoch 6] training loss and accuracy: 0.199 93 %
# [Epoch 6] validation loss and accuracy: 0.500 87 %
# [Epoch 11] training loss and accuracy: 0.066 98 %
# [Epoch 11] validation loss and accuracy: 0.470 89 %
# [Epoch 16] training loss and accuracy: 0.061 98 %
# [Epoch 16] validation loss and accuracy: 0.382 90 %
# [Epoch 21] training loss and accuracy: 0.058 98 %
# [Epoch 21] validation loss and accuracy: 0.413 90 %
# [Epoch 26] training loss and accuracy: 0.007 99 %
# [Epoch 26] validation loss and accuracy: 0.341 90 %
# [Epoch 31] training loss and accuracy: 0.052 98 %
# [Epoch 31] validation loss and accuracy: 0.514 86 %
# [Epoch 21] validation loss and accuracy: 0.487 89 %
# Best validation accuracy: 89 %
# ======================================================
# Model 1 with learning rate=0.0005, momentum=0.9, weight_decay=0
# [Epoch 1] training loss and accuracy: 1.626 50 %
# [Epoch 1] validation loss and accuracy: 0.951 69 %
# [Epoch 6] training loss and accuracy: 0.455 85 %
# [Epoch 6] validation loss and accuracy: 0.572 82 %
# [Epoch 11] training loss and accuracy: 0.306 90 %
# [Epoch 11] validation loss and accuracy: 0.437 86 %
# [Epoch 16] training loss and accuracy: 0.209 93 %
# [Epoch 16] validation loss and accuracy: 0.588 84 %
# [Epoch 21] training loss and accuracy: 0.127 96 %
# [Epoch 21] validation loss and accuracy: 0.465 87 %
# [Epoch 26] training loss and accuracy: 0.081 97 %
# [Epoch 26] validation loss and accuracy: 0.457 88 %
# [Epoch 31] training loss and accuracy: 0.058 98 %
# [Epoch 31] validation loss and accuracy: 0.480 88 %
# [Epoch 36] training loss and accuracy: 0.027 99 %
# [Epoch 36] validation loss and accuracy: 0.502 89 %
# Best validation accuracy: 90 %
# ======================================================
# Model 1 with learning rate=0.0005, momentum=0.9, weight_decay=0.01
# [Epoch 1] training loss and accuracy: 1.909 44 %
# [Epoch 1] validation loss and accuracy: 1.077 66 %
# [Epoch 6] training loss and accuracy: 0.573 82 %
# [Epoch 6] validation loss and accuracy: 0.647 81 %
# [Epoch 11] training loss and accuracy: 0.343 89 %
# [Epoch 11] validation loss and accuracy: 0.557 82 %
# [Epoch 16] training loss and accuracy: 0.224 92 %
# [Epoch 16] validation loss and accuracy: 0.523 86 %
# [Epoch 21] training loss and accuracy: 0.127 96 %
# [Epoch 21] validation loss and accuracy: 0.520 87 %
# [Epoch 26] training loss and accuracy: 0.061 98 %
# [Epoch 26] validation loss and accuracy: 0.534 87 %
# Best validation accuracy: 87 %
# ======================================================
# Model 2 with learning rate=0.01, momentum=0.9, weight_decay=0
# [Epoch 1] training loss and accuracy: 1.015 68 %
# [Epoch 1] validation loss and accuracy: 0.616 81 %
# [Epoch 6] training loss and accuracy: 0.088 97 %
# [Epoch 6] validation loss and accuracy: 0.436 89 %
# [Epoch 11] training loss and accuracy: 0.034 98 %
# [Epoch 11] validation loss and accuracy: 0.460 90 %
# Best validation accuracy: 92 %
# ======================================================
# Model 2 with learning rate=0.01, momentum=0.9, weight_decay=0.01
# [Epoch 1] training loss and accuracy: 1.050 67 %
# [Epoch 1] validation loss and accuracy: 0.643 79 %
# [Epoch 6] training loss and accuracy: 0.072 97 %
# [Epoch 6] validation loss and accuracy: 0.353 90 %
# [Epoch 11] training loss and accuracy: 0.039 98 %
# [Epoch 11] validation loss and accuracy: 0.465 91 %
# [Epoch 16] training loss and accuracy: 0.006 100 %
# [Epoch 16] validation loss and accuracy: 0.300 92 %
# [Epoch 21] training loss and accuracy: 0.091 96 %
# [Epoch 21] validation loss and accuracy: 0.416 90 %
# Best validation accuracy: 92 %
# ======================================================
# Model 2 with learning rate=0.001, momentum=0.9, weight_decay=0
# [Epoch 36] training loss and accuracy: 0.031 99 %
# [Epoch 36] validation loss and accuracy: 0.520 88 %
# Best validation accuracy: 89 %
# ======================================================
# Model 4 with learning rate=0.001, momentum=0.9, weight_decay=0.01
# [Epoch 1] training loss and accuracy: 2.223 25 %
# [Epoch 1] validation loss and accuracy: 1.631 59 %
# [Epoch 6] training loss and accuracy: 0.627 80 %
# [Epoch 6] validation loss and accuracy: 0.667 79 %
# [Epoch 11] training loss and accuracy: 0.372 87 %
# [Epoch 11] validation loss and accuracy: 0.537 83 %
# [Epoch 16] training loss and accuracy: 0.242 91 %
# [Epoch 16] validation loss and accuracy: 0.516 84 %
# [Epoch 21] training loss and accuracy: 0.148 95 %
# [Epoch 21] validation loss and accuracy: 0.458 85 %
# [Epoch 26] training loss and accuracy: 0.089 96 %
# [Epoch 26] validation loss and accuracy: 0.552 86 %
# Best validation accuracy: 87 %
# ======================================================
# Model 4 with learning rate=0.0005, momentum=0.9, weight_decay=0
# [Epoch 1] training loss and accuracy: 2.401 26 %
# [Epoch 1] validation loss and accuracy: 2.201 45 %
# [Epoch 6] training loss and accuracy: 0.705 77 %
# [Epoch 6] validation loss and accuracy: 0.728 76 %
# [Epoch 11] training loss and accuracy: 0.485 84 %
# [Epoch 11] validation loss and accuracy: 0.550 82 %
# [Epoch 16] training loss and accuracy: 0.368 87 %
# [Epoch 16] validation loss and accuracy: 0.534 82 %
# [Epoch 21] training loss and accuracy: 0.270 91 %
# [Epoch 21] validation loss and accuracy: 0.522 84 %
# [Epoch 26] training loss and accuracy: 0.199 93 %
# [Epoch 26] validation loss and accuracy: 0.514 85 %
# [Epoch 31] training loss and accuracy: 0.155 94 %
# [Epoch 31] validation loss and accuracy: 0.550 86 %
# Best validation accuracy: 86 %
# ======================================================
# Model 4 with learning rate=0.0005, momentum=0.9, weight_decay=0.01
# [Epoch 1] training loss and accuracy: 2.478 8 %
# [Epoch 1] validation loss and accuracy: 2.396 24 %
# [Epoch 6] training loss and accuracy: 0.748 75 %
# [Epoch 6] validation loss and accuracy: 0.726 76 %
# [Epoch 11] training loss and accuracy: 0.466 84 %
# [Epoch 11] validation loss and accuracy: 0.612 82 %
# [Epoch 16] training loss and accuracy: 0.371 88 %
# [Epoch 16] validation loss and accuracy: 0.528 83 %
# [Epoch 21] training loss and accuracy: 0.295 90 %
# [Epoch 21] validation loss and accuracy: 0.499 84 %
# [Epoch 26] training loss and accuracy: 0.252 91 %
# [Epoch 26] validation loss and accuracy: 0.455 86 %
# [Epoch 31] training loss and accuracy: 0.187 93 %
# [Epoch 31] validation loss and accuracy: 0.522 85 %
# [Epoch 36] training loss and accuracy: 0.158 94 %
# [Epoch 36] validation loss and accuracy: 0.543 85 %
# Best validation accuracy: 87 %
# ======================================================
# Best model and hyperparameter: {'model': [[4, 8], [5, 5], [64], 0.2, 3], 'lr': 0.01, 'momentum': 0.9, 'weight_decay': 0.01}
# Best validation accuracy: 92 %
# time elapsed:  6506.239713430405

# %%
import pickle
import os

with open('best_model_hyperparam', 'wb') as handle:
    pickle.dump(best_model_hyperparam, handle)

# %% [markdown]
# ## Train using best model and hyperparams

# %%
# set seed
torch.manual_seed(123)
best_model = [[4, 8], [5, 5], [64], 0.2, 3]
best_net = ConvNet(*best_model)
best_net.to(device)
print(best_net)

# init loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(best_net.parameters(), lr=0.01, momentum=0.9, weight_decay=0.01)

NUM_EPOCHS = 50

# train
train_loss_history, train_acc_history, val_loss_history, val_acc_history = \
    train(best_net, train_loader, NUM_EPOCHS, optimizer, criterion, val_loader, print_every=1, print_time=True)
# Out:
# ConvNet(
#   (conv_block): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 4, kernel_size=(5, 5), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): Sequential(
#       (0): Conv2d(4, 8, kernel_size=(5, 5), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (fc_block): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=8192, out_features=64, bias=True)
#       (1): ReLU()
#     )
#   )
#   (scoring): Linear(in_features=64, out_features=12, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# [Epoch 1] training loss and accuracy: 1.104 65 %
# [Epoch 1] validation loss and accuracy: 1.045 68 %
# [Epoch 2] training loss and accuracy: 0.608 80 %
# [Epoch 2] validation loss and accuracy: 0.591 84 %
# [Epoch 3] training loss and accuracy: 0.457 85 %
# [Epoch 3] validation loss and accuracy: 0.567 85 %
# [Epoch 4] training loss and accuracy: 0.325 89 %
# [Epoch 4] validation loss and accuracy: 0.485 86 %
# [Epoch 5] training loss and accuracy: 0.246 92 %
# [Epoch 5] validation loss and accuracy: 0.429 87 %
# [Epoch 6] training loss and accuracy: 0.179 94 %
# [Epoch 6] validation loss and accuracy: 0.460 87 %
# [Epoch 7] training loss and accuracy: 0.143 95 %
# [Epoch 7] validation loss and accuracy: 0.463 87 %
# [Epoch 8] training loss and accuracy: 0.096 97 %
# [Epoch 8] validation loss and accuracy: 0.519 87 %
# [Epoch 9] training loss and accuracy: 0.084 97 %
# [Epoch 9] validation loss and accuracy: 0.414 89 %
# [Epoch 10] training loss and accuracy: 0.066 97 %
# [Epoch 10] validation loss and accuracy: 0.696 85 %
# [Epoch 11] training loss and accuracy: 0.090 96 %
# [Epoch 11] validation loss and accuracy: 0.530 88 %
# [Epoch 12] training loss and accuracy: 0.051 98 %
# [Epoch 12] validation loss and accuracy: 0.476 89 %
# [Epoch 13] training loss and accuracy: 0.032 98 %
# [Epoch 13] validation loss and accuracy: 0.603 89 %
# [Epoch 14] training loss and accuracy: 0.065 98 %
# [Epoch 14] validation loss and accuracy: 0.506 88 %
# [Epoch 15] training loss and accuracy: 0.042 98 %
# [Epoch 15] validation loss and accuracy: 0.500 88 %
# [Epoch 16] training loss and accuracy: 0.041 98 %
# [Epoch 16] validation loss and accuracy: 0.531 88 %
# [Epoch 17] training loss and accuracy: 0.063 98 %
# [Epoch 17] validation loss and accuracy: 0.582 87 %
# [Epoch 18] training loss and accuracy: 0.032 99 %
# [Epoch 18] validation loss and accuracy: 0.510 89 %
# [Epoch 19] training loss and accuracy: 0.014 99 %
# [Epoch 19] validation loss and accuracy: 0.406 90 %
# [Epoch 20] training loss and accuracy: 0.006 99 %
# [Epoch 20] validation loss and accuracy: 0.443 90 %
# [Epoch 21] training loss and accuracy: 0.012 99 %
# [Epoch 21] validation loss and accuracy: 0.491 90 %
# [Epoch 22] training loss and accuracy: 0.032 99 %
# [Epoch 22] validation loss and accuracy: 0.410 89 %
# [Epoch 23] training loss and accuracy: 0.052 98 %
# [Epoch 23] validation loss and accuracy: 0.489 85 %
# [Epoch 24] training loss and accuracy: 0.048 98 %
# [Epoch 24] validation loss and accuracy: 0.475 88 %
# [Epoch 25] training loss and accuracy: 0.024 99 %
# [Epoch 25] validation loss and accuracy: 0.540 89 %
# [Epoch 26] training loss and accuracy: 0.100 97 %
# [Epoch 26] validation loss and accuracy: 0.376 88 %
# [Epoch 27] training loss and accuracy: 0.068 97 %
# [Epoch 27] validation loss and accuracy: 0.456 86 %
# [Epoch 28] training loss and accuracy: 0.036 99 %
# [Epoch 28] validation loss and accuracy: 0.440 89 %
# [Epoch 29] training loss and accuracy: 0.029 99 %
# [Epoch 29] validation loss and accuracy: 0.383 91 %
# [Epoch 30] training loss and accuracy: 0.009 99 %
# [Epoch 30] validation loss and accuracy: 0.417 90 %
# [Epoch 31] training loss and accuracy: 0.008 99 %
# [Epoch 31] validation loss and accuracy: 0.348 90 %
# [Epoch 32] training loss and accuracy: 0.018 99 %
# [Epoch 32] validation loss and accuracy: 0.498 89 %
# [Epoch 33] training loss and accuracy: 0.020 99 %
# [Epoch 33] validation loss and accuracy: 0.351 92 %
# [Epoch 34] training loss and accuracy: 0.011 99 %
# [Epoch 34] validation loss and accuracy: 0.366 90 %
# [Epoch 35] training loss and accuracy: 0.041 98 %
# [Epoch 35] validation loss and accuracy: 0.443 88 %
# [Epoch 36] training loss and accuracy: 0.095 97 %
# [Epoch 36] validation loss and accuracy: 0.459 89 %
# [Epoch 37] training loss and accuracy: 0.059 98 %
# [Epoch 37] validation loss and accuracy: 0.420 89 %
# [Epoch 38] training loss and accuracy: 0.037 98 %
# [Epoch 38] validation loss and accuracy: 0.477 88 %
# [Epoch 39] training loss and accuracy: 0.017 99 %
# [Epoch 39] validation loss and accuracy: 0.440 89 %
# [Epoch 40] training loss and accuracy: 0.006 99 %
# [Epoch 40] validation loss and accuracy: 0.416 91 %
# [Epoch 41] training loss and accuracy: 0.004 100 %
# [Epoch 41] validation loss and accuracy: 0.417 90 %
# time elapsed:  332.74141120910645

# %%
# Plot train and val loss curve
epoch_count = len(train_loss_history)
plt.plot(range(1, epoch_count+1), train_loss_history, 'b')
plt.plot(range(1, epoch_count+1), val_loss_history, 'r')
plt.legend(['Training Loss', 'Val Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(range(1, epoch_count+1, 3))
plt.savefig('loss-curve.png')
plt.show();

# Plot train and val acc curve
plt.plot(range(1, epoch_count+1), train_acc_history, 'b')
plt.plot(range(1, epoch_count+1), val_acc_history, 'r')
plt.legend(['Training Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.xticks(range(1, epoch_count+1, 3))
plt.ylim(None, 100)
plt.savefig('acc-curve.png')
plt.show();

# %%
test_loader = torch.utils.data.DataLoader(test_data, batch_size=32, shuffle=False)
loss, accuracy = eval(best_net, criterion, test_loader)
print(f'Accuracy of the network on the test images: {accuracy} %')
# Out:
# Accuracy of the network on the test images: 90 %
